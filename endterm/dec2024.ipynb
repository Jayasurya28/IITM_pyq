# %% [markdown]
# https://quizpractice.space/question-paper/practise/2/152e6be3-dfb

# %%
for i in range(10):
    if i % 2 == 0:
        print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("hello world")
# Out:
# hello world
